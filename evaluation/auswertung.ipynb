# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hist_avg_10 = pd.read_json("history.json")
hist_avg_20 = pd.read_json("history(1).json")
hist_max = pd.read_json("history(2).json")

# %%
hist_avg_10
# Out:
#            loss       acc     val_loss   val_acc
# 0   3301.679932  0.518788  2476.498779  0.554676
# 1   2090.119385  0.548507  2403.060547  0.538261
# 2   1590.798462  0.534472  2447.413086  0.533250
# 3   1192.569824  0.533705  2588.491699  0.533592
# 4    993.960144  0.534847  2740.043701  0.534062
# 5    913.557373  0.535908  2891.052734  0.529380
# 6    889.606262  0.535019  3293.193848  0.542176
# 7    755.635864  0.534496  3236.255859  0.523186
# 8    582.875977  0.540445  3172.617676  0.535236
# 9    551.128357  0.540820  2941.844727  0.501562
# 10   493.993256  0.540845  3384.195068  0.507167
# 11   476.187012  0.538519  3120.914062  0.523697
# 12   445.543427  0.536210  2953.035645  0.497737
# 13   393.938538  0.537140  2944.627441  0.490595
# 14   383.591797  0.539188  2935.578857  0.497136
# 15   397.199829  0.535818  3193.521484  0.512186
# 16   409.046661  0.539327  3565.318604  0.498166
# 17   482.579163  0.540690  3438.003174  0.488794
# ...

# %%
plt.plot(hist_avg_10.index.values,hist_avg_10["loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(hist_avg_10.index.values,hist_avg_10["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(hist_avg_20.index.values,hist_avg_20["loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(hist_avg_20.index.values,hist_avg_20["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(hist_max.index.values,hist_max["loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(hist_max.index.values,hist_max["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
